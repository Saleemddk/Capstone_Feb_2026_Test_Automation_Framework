# %%
from io import StringIO
import pytest
import boto3
import pandas as pd
from sqlalchemy import create_engine
import cx_Oracle
import logging
import paramiko
mysql_conn = create_engine("mysql+pymysql://root:Admin%40143@localhost:3308/feb2026retaildwh")

# %%
df_foreign_key = pd.read_sql("select * from fact_sales",mysql_conn)

# %%
df_primary_key = pd.read_sql("select * from stag_product",mysql_conn)

# %%
df_not_matched = df_foreign_key[~df_foreign_key['product_id'].isin(df_primary_key['product_id'])]

# %%
df_foreign_key['total_sales'].dtype
# Out:
# dtype('float64')

# %%
list(df_foreign_key.columns)
# Out:
# ['sales_id', 'product_id', 'store_id', 'quantity', 'total_sales', 'sale_date']
